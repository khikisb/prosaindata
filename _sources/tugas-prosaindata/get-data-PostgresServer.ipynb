# %%
pip install psycopg2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.8/dist-packages (2.9.5)

# %%
import psycopg2

# %%
connection = psycopg2.connect(
    host="trumpet.db.elephantsql.com",
    database="prosain{210411100112}",
    user="xtzkuaqv",
    password="kOupjNX9j0ny4IIeAWJpC014w6HPFTA38",
    port="5432"
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-19-6539a8953336> in <module>
# ----> 1 connection = psycopg2.connect(
#       2     host="trumpet.db.elephantsql.com",
#       3     database="prosain{210411100112}",
#       4     user="xtzkuaqv",
#       5     password="kOupjNX9j0ny4IIeAWJpC014w6HPFTA38",
#
# /usr/local/lib/python3.8/dist-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: FATAL:  no pg_hba.conf entry for host "34.125.82.239", user "xtzkuaqv", database "prosain{210411100112}", SSL on
# FATAL:  no pg_hba.conf entry for host "34.125.82.239", user "xtzkuaqv", database "prosain{210411100112}", SSL off

# %%
# Membuat objek cursor
cursor = connection.cursor()

# Mengambil data dari tabel
cursor.execute("Select sepallength From Iris")

# Menampilkan data
cursor.fetchall()
