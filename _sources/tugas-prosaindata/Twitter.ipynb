# %% [markdown]
# # Tugas 1 Crawling data Twitter

# %% [markdown]
# 1. Crawling data twitter untuk memperoleh output akun, tweet, dan lokasi tweet dengan tujuan "Mengidentifikasi respon dari kandidat CAPRES dari ulasan Twitter"
#
# Untuk run code bisa mengunjungi link :
#
# https://colab.research.google.com/drive/1SPLd2CDhvS0AZ72WKSCt9SjWQk77ccNW?usp=sharing

# %%
# !pip3 install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 2.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter
import csv

# %%
# Set the search term and maximum number of tweets to retrieve
search_term = "prabowo"
max_tweets = 1000

# %%
# Open a CSV file for writing and write the header row
with open('output.csv', 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Account', 'Tweet', 'Location'])

    # Loop through the tweets and write each row to the CSV file
    for i, tweet in enumerate(sntwitter.TwitterSearchScraper(f'{search_term} lang:id geocode:-0.7892751,113.9213275,1500km').get_items()):
        if i >= max_tweets:
            break
        location = tweet.location['name'] if hasattr(tweet, 'location') and tweet.location else ""
        writer.writerow([tweet.user.username, tweet.content, location])
# Out:
# <ipython-input-4-ceee1403ef07>:11: FutureWarning: content is deprecated, use rawContent instead
#   writer.writerow([tweet.user.username, tweet.content, location])

# %% [markdown]
# lang:id untuk membatasi pencarian hanya pada bahasa Indonesia,
#
#
# dan geocode:-0.7892751,113.9213275,1500 km
#
# untuk membatasi pencarian hanya pada wilayah Indonesia dengan jarak 1500 kilometer dari pusat koordinat (-0.7892751,113.9213275).
#
# Anda dapat mengubah jarak dan pusat koordinat sesuai kebutuhan Anda.

# %% [markdown]
# File akan disimpan secara otomatis,
# anda bisa mendownloadnya

# %% [markdown]
# ![Screenshot 2023-02-23 055146.png](data:image/png;base64,...)

# %%
import pandas as pd
# Memuat file CSV sebagai dataframe
df = pd.read_csv('output.csv')

# %%
# Menampilkan dataframe menggunakan fungsi display()
display(df)
# Out:
#              Account                                              Tweet  \
# 0       Dannyk717273  @kafiradikalis @prabowo @Gerindra @Dahnilanzar...
# 1        KanopiKeren  Kanopi Transparan Buat Cantik Rumah Kamu!\n\nd...
# 2        jerrysujari  @keuangannews_id Ngakak…! Nggak usah bilang Ke...
# 3        ngopikaliah  @ArgaituGunung @kafiradikalis @prabowo @Gerind...
# 4    nindiaprilia213  Rabu Abu Bu Risma  Gayus Anak Belum Siap jadi ...
# ..               ...                                                ...
# 995     garudatvnews  Prabowo Subianto Didatangi Perdana Menhan Mala...
# 996         ben_1908  @Ayy890_ @Dahnilanzar Pak @prabowo gmn ini jub...
# 997         JatengTV  (12) PT Perorangan memiliki kepastian hukum da...
# 998       elleanor12  @01_TFirmansyah @Gerindra Nich min byk yg belu...
# 999    sejahterahman  @Chaves1305 @prabowo @aniesbaswedan Bisaa ajaa...
#
#      Location
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...
